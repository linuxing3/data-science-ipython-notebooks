-- %%
require 'torch'
-- Out:
-- {
--   deserialize : function: 0x08ceb990
--   cat : function: 0x0914b210
--   cdata : function: 0x08d1cff8
--   newmetatable : function: 0x08d186a0
--   atan2 : function: 0x08d49ca8
--   log : function: 0x08d49910
--   zero : function: 0x0914a928
--   logNormal : function: 0x0914d198
--   sigmoid : function: 0x08d49c08
--   getnumcores : function: 0x08d183c0
--   cross : function: 0x0914b030
--   deserializeFromStorage : function: 0x0915e050
--   inverse : function: 0x0914d2d8
--   updateerrorhandlers : function: 0x08d18808
--   isTypeOf : function: 0x0914ff00
--   ByteStorage : table: 0x08ce4b60
--   prod : function: 0x0914af40
--   ger : function: 0x0914adb0
--   eq : function: 0x0914b440
--   getnumthreads : function: 0x08d18370
--   ByteTensor : table: 0x08d46b10
--   Timer : table: 0x08d48a70
--   addmv : function: 0x0914add8
--   lerp : function: 0x08d49c80
--   match : function: 0x0914abd0
--   Allocator : table: 0x0914f968
--   xcorr2 : function: 0x0914b328
-- ...

-- %%
require 'torchnet'
-- Out:
-- package.torchnet
-- {
--   SplitDataset : table: 0x094d6e70
--   mAPMeter : table: 0x097b7228
--   MultiLabelConfusionMeter : table: 0x097c5460
--   IndexedDatasetWriter : table: 0x09220700
--   TimeMeter : table: 0x09209808
--   Engine : table: 0x095b2700
--   ResampleDataset : table: 0x095d32b0
--   RecallMeter : table: 0x098b33e0
--   CoroutineBatchDataset : table: 0x09591a58
--   Meter : table: 0x09616d60
--   ConfusionMeter : table: 0x097a9130
--   makepackageserializable : function: 0x0959d8f0
--   AUCMeter : table: 0x0979b820
--   Log : table: 0x098eecd0
--   IndexedDatasetReader : table: 0x094a2570
--   AverageValueMeter : table: 0x0978bae0
--   PrecisionAtKMeter : table: 0x09895e68
--   ConcatDataset : table: 0x095c8970
--   TransformDataset : table: 0x09542e98
--   ListDataset : table: 0x094daea8
--   transform :
--     package.torchnet.transform
--     {
--       randperm : function: 0x08cdfab0
--       compose : function: 0x091ba4b0
--       merge : function: 0x095205b0
-- ...

-- %%
?torch.ceil
-- Out:
-- +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
-- [res] torch.ceil([res,] x)
--
--
--  y = torch.ceil(x) returns a new Tensor with the values of the elements
-- of x rounded up to the nearest integers.
--
--  x:ceil() replaces all elements in-place with the values of the elements
-- of x rounded up to the nearest integers.
-- +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

-- %%
require 'image'
-- Out:
-- {
--   yuv2rgb : function: 0x09152b70
--   savePNG : function: 0x0917fa80
--   savePGM : function: 0x0917f978
--   hflip : function: 0x091529e8
--   fabio : function: 0x09152b28
--   convolve : function: 0x09152a48
--   supported_filetypes :
--     {
--       pgm :
--         {
--           loader : function: 0x0917f930
--           saver : function: 0x0917f978
--         }
--       JPEG :
--         {
--           loader : function: 0x0917fb28
--           saver : function: 0x091ea3e8
--         }
--       JPG :
--         {
--           loader : function: 0x0917fb28
--           saver : function: 0x091ea3e8
--         }
--       jpg :
--         {
--           loader : function: 0x0917fb28
--           saver : function: 0x091ea3e8
--         }
--       png :
--         {
--           loader : function: 0x0917f9f8
--           saver : function: 0x0917fa80
--         }
--       ppm :
--         {
--           loader : function: 0x0917f930
--           saver : function: 0x0917f958
-- ...

-- %%
itorch.image({image.lena()})
-- Out:
-- /Users/linuxing3/torch/install/share/lua/5.1/xlua/init.lua:360: module 'libjpeg' not found:
-- 	no field package.preload['libjpeg']
-- 	no file './libjpeg.lua'
-- 	no file '/Users/linuxing3/torch/install/share/luajit-2.1.0-beta1/libjpeg.lua'
-- 	no file '/usr/local/share/lua/5.1/libjpeg.lua'
-- 	no file '/usr/local/share/lua/5.1/libjpeg/init.lua'
-- 	no file '/Users/linuxing3/torch/install/share/lua/5.1/libjpeg.lua'
-- 	no file '/Users/linuxing3/torch/install/share/lua/5.1/libjpeg/init.lua'
-- 	no file './libjpeg.so'
-- 	no file '/usr/local/lib/lua/5.1/libjpeg.so'
-- 	no file '/Users/linuxing3/torch/install/lib/lua/5.1/libjpeg.so'
-- 	no file '/usr/local/lib/lua/5.1/loadall.so'
-- ...
-- Console does not support images

-- %%
itorch.html('<h1>hello xing<h1>')
-- Out:
-- edb83bf6-05e3-44b6-c4a2-4de8e78dc2eb
-- <script type="text/javascript">
--   $(function() {
--     $("#edb83bf6-05e3-44b6-c4a2-4de8e78dc2eb").html('<h1>hello xing<h1>'); // clear any previous plot in window_id
--   });
-- </script>
-- <div id="edb83bf6-05e3-44b6-c4a2-4de8e78dc2eb"></div>
